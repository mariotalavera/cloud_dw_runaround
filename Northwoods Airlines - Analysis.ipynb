# %%
# Snowflake Connection Details. 
options = {
  "sfUrl": "https://hra22104.us-east-1.snowflakecomputing.com",
  "sfUser": "",
  "sfRole": "ACCOUNTADMIN",
  "sfPassword": "", # todo - figure out how to use token instead
  "sfDatabase": "phData",
  "sfSchema": "public",
  "sfWarehouse": "INTERVIEW_WH"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_report_1_snowflake_view = spark.read.format("snowflake").options(**options).option("dbtable", "df_report_1_view").load()
display(df_report_1_snowflake_view)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_report_2_snowflake_view = spark.read.format("snowflake").options(**options).option("dbtable", "df_report_2_view").load()
display(df_report_2_snowflake_view)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_report_3_snowflake_view = spark.read.format("snowflake").options(**options).option("dbtable", "df_report_3_view").load()
display(df_report_3_snowflake_view)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_report_4_snowflake_view = spark.read.format("snowflake").options(**options).option("dbtable", "df_report_4_view").load()
display(df_report_4_snowflake_view)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_report_5_snowflake_view = spark.read.format("snowflake").options(**options).option("dbtable", "df_report_5_view").load()
display(df_report_5_snowflake_view)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_report_6_snowflake_view = spark.read.format("snowflake").options(**options).option("dbtable", "df_report_6_view").load()

display(df_report_6_snowflake_view)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
